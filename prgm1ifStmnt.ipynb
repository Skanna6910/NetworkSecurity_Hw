# %%
import math
import numpy
UID_no = 118406473                                     
Last_Name = "Kanna"
First_Name = "Suprajha" 

def row_trans_enc(msg,key):
  key_len = int(len(key))
  key_list = list(key)
  
  msg_list = list(msg)
  msg_len = int(len(msg))
  CT = ''
  a = msg_len/key_len
  #pad = len(key) - a 
  col = key_len
  row = int(msg_len/col)
  #msg_padded = msg + pad * 'x'

  padwith_msg = int((row*col) - msg_len)
  msg_padded = msg_list.extend('_' * padwith_msg)
  orderlist = numpy.argsort(key_list)

  matrix = []

  for i in range(row):
    a = []
    for j in range(col):
      a.append(msg_padded)
    matrix.append(a) 

  for x in orderlist:
    for y in range(0,len(matrix)):
      CT += matrix[y][x]
  return CT    

msg = input("enter the message: ")
key = input("enter the key value: ")
  
Cipher = row_trans_enc(msg,key) 
print(Cipher)
# Out:
# enter the message: hiil
# enter the key value: 345
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2d849767b02c> in <module>()
#      40 key = input("enter the key value: ")
#      41
# ---> 42 Cipher = row_trans_enc(msg,key)
#      43 print(Cipher)
#      44
#
# <ipython-input-49-2d849767b02c> in row_trans_enc(msg, key)
#      34   for x in orderlist:
#      35     for y in range(0,len(matrix)):
# ---> 36       CT += matrix[y][x]
#      37   return CT
#      38
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
for row in range(key_len):
    ptr = row 
    ciphertxt = ''
    while ptr < key_len:
      ciphertxt[row] += msg[ptr]
      ptr += key
  return ''.join(ciphertxt)

# %%
import math
PT = input("enter the message: ")
k = int(input("enter the key value: "))

def row_trans_enc(PT,k):
 k_ptr = 0 
 CT = ""
 PT_len = int(len(PT))
 PT_list = list(PT)
 key_len = len(k)
 key_list = list(k)

 row,col = (math.ceil(PT_len/key_len), key_len)
 
 padwith_msg = int((row*col) - PT_len)
 PT_padded = msg_list.extend('_' * padwith_msg)
 orderlist = numpy.argsort(key_list)

 matrix = []
 matrix = [PT_list[i:i + col]
           for i in range(0, len(PT_list), col)]
 
 for _ in range(col):
  cur_ptr = k.index(key_list[k_ptr])
  CT += ''.join([row[cur_ptr] for row in matrix])
  k_ptr += 1

 print(CT)
# Out:
# enter the message: hi
# enter the key value: 34

# %%
import math
import numpy
from textwrap import wrap

UID_no = 118406473                                     
Last_Name = "Kanna"
First_Name = "Suprajha"
